# %%
df1 = spark.read.format('csv').options(header='false', inferSchema='true').load('/FileStore/pankaj/gatech/drug_era_csv_1.gz')
df1.printSchema()    
df1 = df1.toDF('drug_era_id','person_id','drug_concept_id','drug_era_start_date','drug_era_end_date','drug_exposure_count','gap_days')
spark.sql("DROP TABLE IF EXISTS pankaj_gt.drug_era1") 
df1.write.saveAsTable("pankaj_gt.drug_era1")
df1.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _c0: integer (nullable = true)
# -- _c1: integer (nullable = true)
# -- _c2: integer (nullable = true)
# -- _c3: timestamp (nullable = true)
# -- _c4: timestamp (nullable = true)
# -- _c5: integer (nullable = true)
# -- _c6: string (nullable = true)
#
# +-----------+---------+---------------+-------------------+-------------------+-------------------+--------+
# drug_era_id|person_id|drug_concept_id|drug_era_start_date|  drug_era_end_date|drug_exposure_count|gap_days|
# +-----------+---------+---------------+-------------------+-------------------+-------------------+--------+
# ...

# %%
df2 = spark.read.format('csv').options(header='false', inferSchema='true').load('/FileStore/pankaj/gatech/drug_era_csv_2.gz')
df2.printSchema()    
df2 = df2.toDF('drug_era_id','person_id','drug_concept_id','drug_era_start_date','drug_era_end_date','drug_exposure_count','gap_days')
spark.sql("DROP TABLE IF EXISTS pankaj_gt.drug_era2") 
df2.write.saveAsTable("pankaj_gt.drug_era2")
df2.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _c0: integer (nullable = true)
# -- _c1: integer (nullable = true)
# -- _c2: integer (nullable = true)
# -- _c3: timestamp (nullable = true)
# -- _c4: timestamp (nullable = true)
# -- _c5: integer (nullable = true)
# -- _c6: string (nullable = true)
#
# +-----------+---------+---------------+-------------------+-------------------+-------------------+--------+
# drug_era_id|person_id|drug_concept_id|drug_era_start_date|  drug_era_end_date|drug_exposure_count|gap_days|
# +-----------+---------+---------------+-------------------+-------------------+-------------------+--------+
# ...

# %%
df3 = spark.read.format('csv').options(header='false', inferSchema='true').load('/FileStore/pankaj/gatech/drug_era_csv_3.gz')
df3.printSchema()    
df3 = df3.toDF('drug_era_id','person_id','drug_concept_id','drug_era_start_date','drug_era_end_date','drug_exposure_count','gap_days')
spark.sql("DROP TABLE IF EXISTS pankaj_gt.drug_era3") 
df3.write.saveAsTable("pankaj_gt.drug_era3")
df3.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _c0: integer (nullable = true)
# -- _c1: integer (nullable = true)
# -- _c2: integer (nullable = true)
# -- _c3: timestamp (nullable = true)
# -- _c4: timestamp (nullable = true)
# -- _c5: integer (nullable = true)
# -- _c6: string (nullable = true)
#
# +-----------+---------+---------------+-------------------+-------------------+-------------------+--------+
# drug_era_id|person_id|drug_concept_id|drug_era_start_date|  drug_era_end_date|drug_exposure_count|gap_days|
# +-----------+---------+---------------+-------------------+-------------------+-------------------+--------+
# ...

# %%
df4 = spark.read.format('csv').options(header='false', inferSchema='true').load('/FileStore/pankaj/gatech/drug_era_csv_4.gz')
df4.printSchema()    
df4 = df4.toDF('drug_era_id','person_id','drug_concept_id','drug_era_start_date','drug_era_end_date','drug_exposure_count','gap_days')
spark.sql("DROP TABLE IF EXISTS pankaj_gt.drug_era4") 
df4.write.saveAsTable("pankaj_gt.drug_era4")
df4.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _c0: integer (nullable = true)
# -- _c1: integer (nullable = true)
# -- _c2: integer (nullable = true)
# -- _c3: timestamp (nullable = true)
# -- _c4: timestamp (nullable = true)
# -- _c5: integer (nullable = true)
# -- _c6: string (nullable = true)
#
# +-----------+---------+---------------+-------------------+-------------------+-------------------+--------+
# drug_era_id|person_id|drug_concept_id|drug_era_start_date|  drug_era_end_date|drug_exposure_count|gap_days|
# +-----------+---------+---------------+-------------------+-------------------+-------------------+--------+
# ...

# %%
df5 = spark.read.format('csv').options(header='false', inferSchema='true').load('/FileStore/pankaj/gatech/drug_era_csv_5.gz')
df5.printSchema()    
df5 = df5.toDF('drug_era_id','person_id','drug_concept_id','drug_era_start_date','drug_era_end_date','drug_exposure_count','gap_days')
spark.sql("DROP TABLE IF EXISTS pankaj_gt.drug_era5") 
df5.write.saveAsTable("pankaj_gt.drug_era5")
df5.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _c0: integer (nullable = true)
# -- _c1: integer (nullable = true)
# -- _c2: integer (nullable = true)
# -- _c3: timestamp (nullable = true)
# -- _c4: timestamp (nullable = true)
# -- _c5: integer (nullable = true)
# -- _c6: string (nullable = true)
#
# +-----------+---------+---------------+-------------------+-------------------+-------------------+--------+
# drug_era_id|person_id|drug_concept_id|drug_era_start_date|  drug_era_end_date|drug_exposure_count|gap_days|
# +-----------+---------+---------------+-------------------+-------------------+-------------------+--------+
# ...

# %%
df6 = spark.read.format('csv').options(header='false', inferSchema='true').load('/FileStore/pankaj/gatech/drug_era_csv_6.gz')
df6.printSchema()    
df6 = df6.toDF('drug_era_id','person_id','drug_concept_id','drug_era_start_date','drug_era_end_date','drug_exposure_count','gap_days')
spark.sql("DROP TABLE IF EXISTS pankaj_gt.drug_era6") 
df6.write.saveAsTable("pankaj_gt.drug_era6")
df6.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _c0: integer (nullable = true)
# -- _c1: integer (nullable = true)
# -- _c2: integer (nullable = true)
# -- _c3: timestamp (nullable = true)
# -- _c4: timestamp (nullable = true)
# -- _c5: integer (nullable = true)
# -- _c6: string (nullable = true)
#
# +-----------+---------+---------------+-------------------+-------------------+-------------------+--------+
# drug_era_id|person_id|drug_concept_id|drug_era_start_date|  drug_era_end_date|drug_exposure_count|gap_days|
# +-----------+---------+---------------+-------------------+-------------------+-------------------+--------+
# ...

# %%
# %sql

create table pankaj_gt.drug_era as select * from pankaj_gt.drug_era1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
insert into pankaj_gt.drug_era select * from pankaj_gt.drug_era2;
insert into pankaj_gt.drug_era select * from pankaj_gt.drug_era3;
insert into pankaj_gt.drug_era select * from pankaj_gt.drug_era4;
insert into pankaj_gt.drug_era select * from pankaj_gt.drug_era5;
insert into pankaj_gt.drug_era select * from pankaj_gt.drug_era6;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>20995466</td><td>20995466</td></tr></tbody></table></div>

# %%
# %sql
select count(*) from pankaj_gt.drug_era;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>125872351</td></tr></tbody></table></div>

# %%
# %sql
select 
20941037
+20936074
+20964434
+20929393
+21105947
+20995466
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>(((((20941037 + 20936074) + 20964434) + 20929393) + 21105947) + 20995466)</th></tr></thead><tbody><tr><td>125872351</td></tr></tbody></table></div>
